# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import numpy as np

data = pd.read_csv('household_power_consumption.csv')
data
# Out:
#          index       Date      Time Global_active_power Global_reactive_power  \
# 0            0     1/1/07   0:00:00                2.58                 0.136
# 1            1     1/1/07   0:01:00               2.552                   0.1
# 2            2     1/1/07   0:02:00                2.55                   0.1
# 3            3     1/1/07   0:03:00                2.55                   0.1
# 4            4     1/1/07   0:04:00               2.554                   0.1
# ...        ...        ...       ...                 ...                   ...
# 260635  260635  30/6/2007  23:55:00                2.88                  0.36
# 260636  260636  30/6/2007  23:56:00               2.892                 0.358
# 260637  260637  30/6/2007  23:57:00               2.882                  0.28
# 260638  260638  30/6/2007  23:58:00                2.66                  0.29
# 260639  260639  30/6/2007  23:59:00               2.548                 0.354
#
# ...

# %%
data.drop(data[data['Voltage'] == '?'].index, inplace=True)

# %%
data[['Global_active_power', 'Global_reactive_power',
    'Voltage', 'Global_intensity', 'Sub_metering_1',
      'Sub_metering_2']]=data[['Global_active_power', 'Global_reactive_power',
    'Voltage', 'Global_intensity', 'Sub_metering_1', 'Sub_metering_2']].astype(float)

# %%
data.describe()
# Out:
#                index  Global_active_power  Global_reactive_power  \
# count  256869.000000        256869.000000          256869.000000
# mean   129723.522597             1.164937               0.123729
# std     75622.856526             1.181832               0.111872
# min         0.000000             0.082000               0.000000
# 25%     64219.000000             0.296000               0.000000
# 50%    128439.000000             0.564000               0.104000
# 75%    196379.000000             1.606000               0.194000
# max    260639.000000            10.670000               1.148000
#
#              Voltage  Global_intensity  Sub_metering_1  Sub_metering_2  \
# count  256869.000000     256869.000000   256869.000000   256869.000000
# mean      239.208981          4.974755        1.332481        1.670610
# std         3.592793          4.999493        6.704970        6.631361
# min       223.490000          0.400000        0.000000        0.000000
# ...

# %%
sn.displot(data['Global_active_power']);
data['Global_active_power'].var()
# Out:
# 1.3967273884381204

# %%
data['Global_active_power'].mode()[0]
# Out:
# 0.216

# %% [markdown]
# the global active power is positively skewed
# The Global_active_power:
# mean: 0.123729,
# median:0.564,
# mode:0.216,
# 50th percentile: 0.104,
# std:0.111872,
# variance: 1.39672,
# values:0.082000-10.67000.

# %%
sn.displot(data['Global_reactive_power']);
data['Global_reactive_power'].var()
# Out:
# 0.012515277758559793

# %%
data['Global_reactive_power'].mode()[0]
# Out:
# 0.0

# %% [markdown]
# The Global_reactive_power:
# mean: 1.164937
# median:0.104
# mode:0.0
# 50th percentile: is 0.564
# standard deviation: 1.18182
# variance:0.012515
# values:0.0-1.148000

# %%
sn.displot(data['Voltage']);
data['Voltage'].var()
# Out:
# 12.908163954458935

# %%
data['Voltage'].mode()[0]
# Out:
# 240.67

# %% [markdown]
# Voltage
# mean: 239.208931
# median:239.61
# mode:240.67
# the 50th percentile: 239.61
# the standard variation: 3.592793
# the variance: 12.90816
# values:223.490000-250.890000
#
# The voltage is normally distributed.

# %%
sn.displot(data['Global_intensity']);
data['Global_intensity'].var()
# Out:
# 24.994931629221224

# %%
data['Global_intensity'].mode()[0]
# Out:
# 1.4

# %% [markdown]
# Global_intensity
# mean:4.974755
# median:2.6
# mode:1.4
# 50th percentile:2.600000
# standard deviation:4.999493
# variance:24.99493
# values:0.400000	-46.400000
#
# the global intensity is positively skewed

# %%
sn.displot(data['Sub_metering_1']);
data['Sub_metering_1'].var()
# Out:
# 44.956626801649676

# %%
data['Sub_metering_1'].mode()[0]
# Out:
# 0.0

# %% [markdown]
# The Sub_metering_1
# mean:256869.000000
# median:0.0
# mode:0.0
# 50th percentile:0.0
# standard deviaton:6.704970
# variance:44.95662
# values:0.0 -78.000
#
# the Sub_metering_1 is positively skewed

# %%
sn.displot(data['Sub_metering_2']);
data['Sub_metering_2'].var()
# Out:
# 43.974953432975404

# %%
data['Sub_metering_2'].mode()[0]
# Out:
# 0.0

# %% [markdown]
# The Sub_metering_2
# mean:1.670610
# median: 0.0
# mode: 0.0
# 50th percentile: 0.0
# standard deviaton:6.631361
# variance:43.97495
# values:0.0 -78.00

# %%
sn.displot(data['Sub_metering_3']);
data['Sub_metering_3'].var()
# Out:
# 67.02220595313469

# %%
data['Sub_metering_3'].mode()[0]
# Out:
# 0.0

# %% [markdown]
# The Sub_metering_3
# mean:5.831825
# median:0.0
# mode:0.0
# 50th percentile:0.0
# standard deviaton:8.186709
# variance:67.0222
# values:0.0-20.000

# %%
sn.boxplot(data['Sub_metering_1']);

# %%
sn.boxplot(data['Sub_metering_2']);

# %%
sn.boxplot(data['Sub_metering_3']);

# %% [markdown]
# ## General Report

# %% [markdown]
# There are 256869 entries and 10 columns
# namely: Date, Time, Global_active_power, Global_reactive_power, Voltage, Global_intensity, Sub_metering_1, Sub_metering_2, Sub_metering_3
